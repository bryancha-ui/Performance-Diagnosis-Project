# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('주문 시간별(메뉴별)_갤러리아압구정.xlsx',names=['a','b','c','주문시간','반품일시','상품분류','상품코드','상품명','상품단가','주문건수','폐기건수','주문금액','할인금액','실매출합계','부가세액','순매출','기타금액','총합계','결제수단'])
df
# Out:
#                                                              a             b  \
#                                                            NaN           NaN
# 관 리 점 :        가 맹 점 :667M000008    시나본 갤러리아명품관...         NaN           NaN
#                                                            NaN           NaN
# No                                                       가맹점코드          가맹점명
# 1                                                   667M000008  시나본 갤러리아명품관점
# ...                                                        ...           ...
# 7132                                                       NaN           NaN
# 0                                                          NaN           NaN
# 판 매                                                        NaN           NaN
# 취 소                                                        NaN           NaN
# TOTAL                                                      NaN           NaN
#
# ...

# %%
df.drop(['a','b','c'],axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/bq/fx32wzws4hl9rlwvtlhf8zf00000gn/T/ipykernel_9480/2907886202.py in <module>
# ----> 1 df.drop(['a','b','c'],axis=1, inplace=True)
#       2 df
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df.drop([0,1,2,3],axis=0, inplace=True)
df.head()
# Out:
#                                                         주문시간  반품일시  상품분류  \
#                                                          NaN   NaN   NaN
# 관 리 점 :        가 맹 점 :667M000008    시나본 갤러리아명품관...       NaN   NaN   NaN
#                                                          NaN   NaN   NaN
# No                                                      주문시간  반품일시  상품분류
# 4                                                   11:38:59   NaN    커피
#
#                                                     상품코드   상품명  상품단가  주문건수  \
#                                                      NaN   NaN   NaN   NaN
# 관 리 점 :        가 맹 점 :667M000008    시나본 갤러리아명품관...   NaN   NaN   NaN   NaN
#                                                      NaN   NaN   NaN   NaN
# No                                                  상품코드   상품명  상품단가  주문건수
# 4                                                   1005  카페라떼  4600     1
#
# ...

# %%
df = df[df.주문시간 != "소계"]
df
# Out:
#                                                         주문시간  반품일시  상품분류  \
#                                                          NaN   NaN   NaN
# 관 리 점 :        가 맹 점 :667M000008    시나본 갤러리아명품관...       NaN   NaN   NaN
#                                                          NaN   NaN   NaN
# No                                                      주문시간  반품일시  상품분류
# 4                                                   11:38:59   NaN    커피
# ...                                                      ...   ...   ...
# 7131                                                19:35:23   NaN  시나본롤
# 7132                                                     NaN   NaN   NaN
# 판 매                                                      NaN   NaN   NaN
# 취 소                                                      NaN   NaN   NaN
# TOTAL                                                    NaN   NaN   NaN
#
#                                                     상품코드         상품명  \
# ...

# %%
df.drop(['a','b','c'],axis=1, inplace=True)
df.drop(0,axis=0,inplace=True)

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/bq/fx32wzws4hl9rlwvtlhf8zf00000gn/T/ipykernel_9480/3851590278.py in <module>
#       1 df.drop(['a','b','c'],axis=1, inplace=True)
# ----> 2 df.drop(0,axis=0,inplace=True)
#       3
#       4 df
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df.fillna(method='ffill')
# Out:
#                                                              a             b  \
#                                                            NaN           NaN
# 관 리 점 :        가 맹 점 :667M000008    시나본 갤러리아명품관...         NaN           NaN
#                                                            NaN           NaN
# No                                                       가맹점코드          가맹점명
# 1                                                   667M000008  시나본 갤러리아명품관점
# ...                                                        ...           ...
# 7131                                                667M000008  시나본 갤러리아명품관점
# 7132                                                667M000008  시나본 갤러리아명품관점
# 판 매                                                 667M000008  시나본 갤러리아명품관점
# 취 소                                                 667M000008  시나본 갤러리아명품관점
# TOTAL                                               667M000008  시나본 갤러리아명품관점
#
# ...

# %%
df[df.주문시간 ==""] = np.NaN

# %%
df
# Out:
#                                                              a             b  \
#                                                            NaN           NaN
# 관 리 점 :        가 맹 점 :667M000008    시나본 갤러리아명품관...         NaN           NaN
#                                                            NaN           NaN
# No                                                       가맹점코드          가맹점명
# 1                                                   667M000008  시나본 갤러리아명품관점
# ...                                                        ...           ...
# 7131                                                       NaN           NaN
# 7132                                                       NaN           NaN
# 판 매                                                        NaN           NaN
# 취 소                                                        NaN           NaN
# TOTAL                                                      NaN           NaN
#
# ...

# %%
df.fillna(method='ffill')
# Out:
#                                                              a             b  \
#                                                            NaN           NaN
# 관 리 점 :        가 맹 점 :667M000008    시나본 갤러리아명품관...         NaN           NaN
#                                                            NaN           NaN
# No                                                       가맹점코드          가맹점명
# 1                                                   667M000008  시나본 갤러리아명품관점
# ...                                                        ...           ...
# 7131                                                667M000008  시나본 갤러리아명품관점
# 7132                                                667M000008  시나본 갤러리아명품관점
# 판 매                                                 667M000008  시나본 갤러리아명품관점
# 취 소                                                 667M000008  시나본 갤러리아명품관점
# TOTAL                                               667M000008  시나본 갤러리아명품관점
#
# ...

# %%
df.to_excel('갤러리아시간별전처리.xlsx')
