# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
data = pd.read_excel('주문 시간별(메뉴별)_갤러리아압구정.xlsx',names=['a','b','c','주문일자','주문시간','반품일시','상품분류','상품코드','상품명','상품단가','주문건수','폐기건수','주문금액','할인금액','실매출합계','부가세액','순매출','기타금액','총합계','결제수단'])

# %%
data.info
# Out:
# <bound method DataFrame.info of                                                       a           b  \
# 0                                                               NaN
# 1     관 리 점 :        가 맹 점 :667M000008    시나본 갤러리아명품...         NaN
# 2                                                               NaN
# 3                                                    No       가맹점코드
# 4                                                     1  667M000008
# ...                                                 ...         ...
# 7135                                               7132         NaN
# 7136                                                  0         NaN
# 7137                                                판 매         NaN
# 7138                                                취 소         NaN
# 7139                                              TOTAL         NaN
#
#                  c        주문일자      주문시간  반품일시  상품분류  상품코드         상품명  \
# ...

# %%
data.head(100)
# Out:
#                                                     a           b  \
# 0                                                             NaN
# 1   관 리 점 :        가 맹 점 :667M000008    시나본 갤러리아명품...         NaN
# 2                                                             NaN
# 3                                                  No       가맹점코드
# 4                                                   1  667M000008
# ..                                                ...         ...
# 95                                                 92         NaN
# 96                                                 93         NaN
# 97                                                 94         NaN
# 98                                                 95         NaN
# 99                                                 96         NaN
#
#                c        주문일자      주문시간  반품일시  상품분류  상품코드           상품명   상품단가  \
# 0            NaN         NaN       NaN   NaN   NaN   NaN           NaN    NaN
# ...

# %%
data.drop(['a','b','c'],axis=1, inplace=True)

# %%
data.head()
# Out:
#          주문일자      주문시간  반품일시  상품분류  상품코드         상품명  상품단가  주문건수  폐기건수  주문금액  \
# 0         NaN       NaN   NaN   NaN   NaN         NaN   NaN   NaN   NaN   NaN
# 1         NaN       NaN   NaN   NaN   NaN         NaN   NaN   NaN   NaN   NaN
# 2         NaN       NaN   NaN   NaN   NaN         NaN   NaN   NaN   NaN   NaN
# 3        주문일자      주문시간  반품일시  상품분류  상품코드         상품명  상품단가  주문건수  폐기건수  주문금액
# 4  2019-01-02  11:12:27   NaN  시나본롤  1035  클래식바이츠(4개)  4100     1     0  4100
#
#    할인금액  실매출합계  부가세액   순매출  기타금액   총합계  결제수단
# 0   NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 3  할인금액  실매출합계  부가세액   순매출  기타금액   총합계  결제수단
# 4     0   4100   373  3727     0  4100   NaN

# %%
data.drop([0,1,2],axis=0, inplace=True)
data.head()
# Out:
#          주문일자      주문시간  반품일시  상품분류  상품코드            상품명  상품단가  주문건수  폐기건수  \
# 3        주문일자      주문시간  반품일시  상품분류  상품코드            상품명  상품단가  주문건수  폐기건수
# 4  2019-01-02  11:12:27   NaN  시나본롤  1035     클래식바이츠(4개)  4100     1     0
# 5  2019-01-02  11:16:11   NaN  시나본롤  1033  카라멜 피칸 Mini 본  3800     1     0
# 6  2019-01-02       NaN   NaN   NaN  1031     클래식 Mini 본  3300     1     0
# 7  2019-01-02  11:38:59   NaN    커피  1005           카페라떼  4600     1     0
#
#    주문금액  할인금액  실매출합계  부가세액   순매출  기타금액   총합계  결제수단
# 3  주문금액  할인금액  실매출합계  부가세액   순매출  기타금액   총합계  결제수단
# 4  4100     0   4100   373  3727     0  4100   NaN
# 5  3800     0   3800   345  3455     0  3800   NaN
# 6  3300     0   3300   300  3000     0  3300   NaN
# 7  4600     0   4600   418  4182     0  4600   NaN

# %%
data.head(100)
# Out:
#            주문일자      주문시간  반품일시  상품분류  상품코드            상품명   상품단가  주문건수  폐기건수  \
# 3          주문일자      주문시간  반품일시  상품분류  상품코드            상품명   상품단가  주문건수  폐기건수
# 4    2019-01-02  11:12:27   NaN  시나본롤  1035     클래식바이츠(4개)   4100     1     0
# 5    2019-01-02  11:16:11   NaN  시나본롤  1033  카라멜 피칸 Mini 본   3800     1     0
# 6    2019-01-02       NaN   NaN   NaN  1031     클래식 Mini 본   3300     1     0
# 7    2019-01-02  11:38:59   NaN    커피  1005           카페라떼   4600     1     0
# ..          ...       ...   ...   ...   ...            ...    ...   ...   ...
# 98   2019-01-02       NaN   NaN   시나팩  1038    (4)C4클래식시나팩  17500     1     0
# 99   2019-01-02  19:10:02   NaN    콤보  1043     1.커피시나본 콤보   7600     1     0
# 100  2019-01-02  19:17:54   NaN   시나팩  1061     (3)더블피칸미니팩  13500     1     0
# 101  2019-01-02  19:41:31   NaN  시나본롤  1032       카라멜 피칸 본   5100     1     0
# 102  2019-01-02       NaN   NaN   NaN  1030          클래식 본   4500     1     0
#
# ...

# %%
data.drop(3,axis=0,inplace=True)
data.head(135)
# Out:
#            주문일자      주문시간 반품일시  상품분류  상품코드            상품명   상품단가 주문건수 폐기건수  \
# 4    2019-01-02  11:12:27  NaN  시나본롤  1035     클래식바이츠(4개)   4100    1    0
# 5    2019-01-02  11:16:11  NaN  시나본롤  1033  카라멜 피칸 Mini 본   3800    1    0
# 6    2019-01-02       NaN  NaN   NaN  1031     클래식 Mini 본   3300    1    0
# 7    2019-01-02  11:38:59  NaN    커피  1005           카페라떼   4600    1    0
# 8    2019-01-02  11:47:42  NaN  시나본롤  1030          클래식 본   4500    1    0
# ..          ...       ...  ...   ...   ...            ...    ...  ...  ...
# 134  2019-01-03  13:44:21  NaN  시나본롤  1034       Mini 초코본   3500    3    0
# 135  2019-01-03  13:55:29  NaN  시나본롤  1030          클래식 본   4500    1    0
# 136  2019-01-03  14:12:08  NaN  시나본롤  1031     클래식 Mini 본   3300    4    0
# 137  2019-01-03  14:20:50  NaN   시나팩  1061     (3)더블피칸미니팩  13500    1    0
# 138  2019-01-03  14:22:23  NaN    MD  3100     무료_리유저블텀블러      0    1    0
#
#       주문금액 할인금액  실매출합계  부가세액    순매출 기타금액    총합계 결제수단
# ...

# %%
data['상품명'].value_counts()
# Out:
# 클래식 본           1061
# 클래식 Mini 본       861
# 클래식바이츠(4개)       842
# 버라이어티(4개)        603
# Mini 초코본         457
#                 ...
# 메탈롱단품              1
# 우유                 1
# ice잉글리쉬블랙퍼스트       1
# 카라멜 애플 Mini본       1
# 콤보_망고피지            1
# Name: 상품명, Length: 74, dtype: int64

# %%
data['주문시간']
# Out:
# 4       11:12:27
# 5       11:16:11
# 6            NaN
# 7       11:38:59
# 8       11:47:42
#           ...
# 7135         NaN
# 7136          소계
# 7137         NaN
# 7138         NaN
# 7139         NaN
# Name: 주문시간, Length: 7136, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/bq/fx32wzws4hl9rlwvtlhf8zf00000gn/T/ipykernel_10035/2522960898.py in <module>
# ----> 1 df.head(50)
#
# NameError: name 'df' is not defined

# %%
#data2 = pd.read_csv('date.csv')
#data2

#daylist=data2['day'].tolist()

# %%
#df['date']=daylist
#df.drop(['주문일자','주문시간','반품일시','상품분류','상품코드'],axis=1, inplace=True)
#df= df.set_index('date')

#df

# %%
data.to_excel('abc.xlsx')
